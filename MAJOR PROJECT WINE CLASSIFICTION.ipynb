# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("wine classification.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    1
# density                 0
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# 2      9.8      5.0
# ...

# %%
df.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide     True
# density                 False
# pH                       True
# sulphates               False
# alcohol                 False
# quality                  True
# dtype: bool

# %%
df.dropna(subset=['total sulfur dioxide', 'pH', 'quality'], inplace=True)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                 float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1596 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1596 non-null   float64
#  1   volatile acidity      1596 non-null   float64
#  2   citric acid           1596 non-null   float64
#  3   residual sugar        1596 non-null   float64
#  4   chlorides             1596 non-null   float64
#  5   free sulfur dioxide   1596 non-null   float64
#  6   total sulfur dioxide  1596 non-null   float64
#  7   density               1596 non-null   float64
#  8   pH                    1596 non-null   float64
#  9   sulphates             1596 non-null   float64
#  10  alcohol               1596 non-null   float64
#  11  quality               1596 non-null   float64
# dtypes: float64(12)
# memory usage: 162.1 KB

# %%
df.quality
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       6.0
# 4       5.0
#        ...
# 1594    5.0
# 1595    6.0
# 1596    6.0
# 1597    5.0
# 1598    6.0
# Name: quality, Length: 1596, dtype: float64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1596.000000       1596.000000  1596.000000     1596.000000
# mean        8.321366          0.527666     0.271128        2.536936
# std         1.742121          0.179154     0.194847        1.408341
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1596.000000          1596.000000           1596.000000  1596.000000
# mean      0.087487            15.882206             46.431078     0.996745
# std       0.047107            10.467380             32.893072     0.001889
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255955     0.672203
# volatile acidity          -0.255955          1.000000    -0.552080
# citric acid                0.672203         -0.552080     1.000000
# residual sugar             0.115542          0.002286     0.143201
# chlorides                  0.093517          0.061452     0.203904
# free sulfur dioxide       -0.154348         -0.009960    -0.061621
# total sulfur dioxide      -0.112605          0.076832     0.034873
# density                    0.668689          0.021761     0.365526
# pH                         0.026958         -0.046243     0.008324
# sulphates                  0.183046         -0.260504     0.312146
# alcohol                   -0.062419         -0.201591     0.109062
# quality                    0.124090         -0.390616     0.226261
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
corr = df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3.0           8.360000          0.884500     0.171000        2.635000
# 4.0           7.779245          0.693962     0.174151        2.694340
# 5.0           8.168483          0.576959     0.243873        2.523490
# 6.0           8.349765          0.497292     0.273925        2.478100
# 7.0           8.872362          0.403920     0.375176        2.720603
# 8.0           8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3.0       0.122500            11.000000             24.900000  0.997464
# 4.0       0.090679            12.264151             36.245283  0.996542
# 5.0       0.092786            16.992636             56.480118  0.997102
# 6.0       0.084965            15.723705             40.836735  0.996614
# 7.0       0.076588            14.045226             35.020101  0.996104
# ...

# %%
sns.countplot(x=df['quality'])
plt.show()

# %%
sns.distplot(x=df['alcohol'])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(df.query('quality > 2').quality)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Density'>

# %%
sns.countplot(df['fixed acidity'])
plt.show()

# %%
sns.countplot(df['volatile acidity'])
plt.show()

# %%
sns.countplot(df['citric acid'])
plt.show()

# %%
sns.pairplot(df)

# %%
df.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# fixed acidity              AxesSubplot(0.125,0.712609;0.168478x0.167391)
# volatile acidity        AxesSubplot(0.327174,0.712609;0.168478x0.167391)
# citric acid             AxesSubplot(0.529348,0.712609;0.168478x0.167391)
# residual sugar          AxesSubplot(0.731522,0.712609;0.168478x0.167391)
# chlorides                  AxesSubplot(0.125,0.511739;0.168478x0.167391)
# free sulfur dioxide     AxesSubplot(0.327174,0.511739;0.168478x0.167391)
# total sulfur dioxide    AxesSubplot(0.529348,0.511739;0.168478x0.167391)
# density                 AxesSubplot(0.731522,0.511739;0.168478x0.167391)
# pH                          AxesSubplot(0.125,0.31087;0.168478x0.167391)
# sulphates                AxesSubplot(0.327174,0.31087;0.168478x0.167391)
# alcohol                  AxesSubplot(0.529348,0.31087;0.168478x0.167391)
# quality                  AxesSubplot(0.731522,0.31087;0.168478x0.167391)
# dtype: object

# %%
df.hist(figsize=(10,10),bins=50)
plt.show()

# %%
df['goodquality'] =[1 if x >= 7 else 0 for x in df['quality']]
X = df.drop(['quality','goodquality'], axis = 1)
Y = df['goodquality']

# %%
df['goodquality'].value_counts()
# Out:
# 0    1379
# 1     217
# Name: goodquality, dtype: int64

# %% [markdown]
# A wine is excellent if it reaches more than 7, and good if its rate is between 5 and 7.

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
from sklearn.ensemble import ExtraTreesClassifier
classifier = ExtraTreesClassifier()
classifier.fit(X,Y)
# Out:
# ExtraTreesClassifier()

# %%
score = classifier.feature_importances_
print(score)
# Out:
# [0.08293192 0.11089193 0.10036385 0.07814944 0.07326463 0.07157506
#  0.0877831  0.09064353 0.01147563 0.11586181 0.17705911]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %% [markdown]
# # REGRESSIONS

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train,Y_train)
Y_pred = model.predict(X_test)


from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy Score:",accuracy_score(Y_test,Y_pred))
# Out:
# Accuracy Score: 0.8622129436325678

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

model = LinearRegression()
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.8308977035490606

# %%
confusion_mat = confusion_matrix(Y_test,Y_pred)
print(confusion_mat)
# Out:
# [[390  12]
#  [ 54  23]]

# %% [markdown]
# # CLASSIFIERS

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.8747390396659708

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred2))
# Out:
# Accuracy Score: 0.8935281837160751

# %%
from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.8308977035490606

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
pred_y = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,pred_y))
# Out:
# Accuracy Score: 0.8392484342379958

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,Y_train)
y_pred3 = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred3))
# Out:
# Accuracy Score: 0.7933194154488518

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 99.8/99.8 MB 6.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb
model5 = xgb.XGBClassifier(random_state=1)
model5.fit(X_train, Y_train)
y_pred5 = model5.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred5))
# Out:
# Accuracy Score: 0.8956158663883089

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','LinearRegression','Decision Tree','Random Forest', 'KNN','SVC','GaussianNB','Xgboost'],
    'Score': [0.862,0.830,0.874,0.893,0.830,0.839,0.793,0.895]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df
# Out:
#                      Model
# Score
# 0.895              Xgboost
# 0.893        Random Forest
# 0.874        Decision Tree
# 0.862  Logistic Regression
# 0.839                  SVC
# 0.830     LinearRegression
# 0.830                  KNN
# 0.793           GaussianNB

# %% [markdown]
# for traing the model i will use Xgboost and Random Forest
